# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %% [markdown]
# J'ai tout d'abord importé les fonctions de base pour pouvoir faire fonctionner adéquatement le script.

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %% [markdown]
# J'ai suivi de nouveau les étapes proposées dans le tutoriel.

# %%
demandes = pd.read_csv("ati.csv")

# %% [raw]
# J'ai utilisé la fonction, telle que vue en classe, pour lire le fichier csv.

# %%
demandes
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %% [markdown]
# J'ai seulement voulu testé le fichier pour voir les catégories et la structure.

# %%
demandes.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
demandes.columns = ['Année', 'Mois', 'Numéro_de_requête', 'Description_en_anglais', 'Description_en_français', 'Résultat', 'Pages', 'Acronyme', 'Nom']

# %% [markdown]
# J'ai changé le nom des colonnes pour qu'elles soient en français et plus simples.

# %%
demandes
# Out:
#        Année  Mois Numéro_de_requête  \
# 0       2016     3      A-2015-00070
# 1       2015     4      A-2015-00001
# 2       2015     4      A-2014-00219
# 3       2015     4      A-2014-00218
# 4       2015     4      A-2014-00217
# 5       2015     4      A-2014-00216
# 6       2015     4      A-2014-00214
# 7       2015     4      A-2014-00210
# 8       2015     4      A-2014-00213
# 9       2015     6      A-2015-00012
# 10      2015     4      A-2014-00212
# 11      2015     4      A-2014-00200
# 12      2015     4      A-2014-00140
# 13      2015     5      A-2015-00003
# 14      2015     4      A-2014-00112
# 15      2015     5      A-2014-00211
# 16      2015     4      A-2014-00098
# 17      2015     4      A-2014-00070
# 18      2015     4      A-2015-00009
# 19      2015     5      A-2015-00011
# 20      2015     5      A-2015-00010
# 21      2015     5      A-2015-00006
# 22      2015     5      A-2014-00209
# 23      2015     5      A-2014-00145
# ...

# %% [markdown]
# Encore une fois, j'ai simplement voulu tester le fichier pour voir si les noms des colonnes avaient bien changé.

# %%
demandes.Nom.value_counts().head(10)
# Out:
# National Defence | Défense nationale                                                          2605
# Global Affairs Canada | Affaires mondiales Canada                                             1650
# Employment and Social Development Canada | Emploi et Développement social Canada              1541
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada    1323
# Health Canada | Santé Canada                                                                  1164
# Royal Canadian Mounted Police | Gendarmerie royale du Canada                                  1121
# Public Services and Procurement Canada | Services publics et Approvisionnement Canada         1116
# Canada Revenue Agency | Agence du revenu du Canada                                            1046
# Transport Canada | Transports Canada                                                          1026
# ...

# %% [markdown]
# Dans un premier temps, à l'aide de la fonction value_counts et head pour déterminer quels organismes avaient reçu le plus de demandes.

# %%
demandes.groupby("Nom").Année.value_counts()
# Out:
# Nom                                                                                                          Année
# Administrative Tribunals Support Service of Canada | Service canadien d'appui aux tribunaux administratifs   2016      13
#                                                                                                              2015      11
#                                                                                                              2017       1
# Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada                                     2016     155
#                                                                                                              2015      83
#                                                                                                              2017       7
# Asia-Pacific Foundation of Canada | Fondation Asie Pacifique du Canada                                       2015       1
# ...

# %% [markdown]
# J'ai eu recours aux fonctions groupby et value_counts, j'ai voulu savoir combien de demandes par année chaque organisme avait reçu.

# %%
demandes.groupby("Nom").Année.value_counts().sort_values(ascending=False)
# Out:
# Nom                                                                                                                                    Année
# National Defence | Défense nationale                                                                                                   2016     1313
#                                                                                                                                        2015     1163
# Employment and Social Development Canada | Emploi et Développement social Canada                                                       2016      954
# Global Affairs Canada | Affaires mondiales Canada                                                                                      2016      898
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                             2015      653
# ...

# %% [markdown]
# Par la suite, j'ai simplement classé les résultats précédemment obtenus pour savoir quel organisme avait reçu le plus de demandes en une seule année.

# %%
refus = demandes.Pages==0

# %%
demandes[refus].Nom.value_counts()
# Out:
# National Defence | Défense nationale                                                                                                                             611
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       393
# Royal Canadian Mounted Police | Gendarmerie royale du Canada                                                                                                     289
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                283
# Privy Council Office | Bureau du Conseil privé                                                                                                                   282
# ...

# %% [markdown]
# J'ai créé une variable qui répertoriait tous les cas où le nombre de pages fournis équivalait à 0. J'ai ensuite classé tous ces cas, grâce à la fonction value_counts, pour déterminer quel organisme n'avait pas pu fournir les documents demandés pour des raisons variables.
